# %% [markdown]
# ## Pymaceuticals Inc.

# %% [markdown]
# ### Analysis

# %%
# Dependencies and Setup
import pandas as pd
import matplotlib.pyplot as plt
import scipy.stats as st
import numpy as np
import scipy.stats as st

# %%
# Call the files
mouse_metadata_path = "data/Mouse_metadata.csv"
study_results_path = "data/Study_results.csv"

# Read the files
mouse_metadata = pd.read_csv(mouse_metadata_path)
study_results = pd.read_csv(study_results_path)

# %%
# combine the files - display for preview
combinedDF = pd.merge(study_results, mouse_metadata, how="left", on="Mouse ID")
combinedDF.head()
# Out:
#   Mouse ID  Timepoint  Tumor Volume (mm3)  Metastatic Sites Drug Regimen  \
# 0     b128          0                45.0                 0    Capomulin
# 1     f932          0                45.0                 0     Ketapril
# 2     g107          0                45.0                 0     Ketapril
# 3     a457          0                45.0                 0     Ketapril
# 4     c819          0                45.0                 0     Ketapril
#
#       Sex  Age_months  Weight (g)
# 0  Female           9          22
# 1    Male          15          29
# 2  Female           2          29
# 3  Female          11          30
# 4    Male          21          25

# %%
# Checking the number of mice.
combinedDF["Mouse ID"].nunique()
# Out:
# 249

# %%
# Getting the duplicate mice by ID number that shows up for Mouse ID and Timepoint. 

duplicateMouseID = combinedDF.loc[combinedDF.duplicated(subset=["Mouse ID", "Timepoint"]), "Mouse ID"].unique()

duplicateMouseID
# Out:
# array(['g989'], dtype=object)

# %%
# Optional: Get all the data for the duplicate mouse ID. 
duplicateMouseID = combinedDF.loc[combinedDF["Mouse ID"] == "g989", :]
duplicateMouseID
# Out:
#      Mouse ID  Timepoint  Tumor Volume (mm3)  Metastatic Sites Drug Regimen  \
# 107      g989          0           45.000000                 0     Propriva
# 137      g989          0           45.000000                 0     Propriva
# 329      g989          5           48.786801                 0     Propriva
# 360      g989          5           47.570392                 0     Propriva
# 620      g989         10           51.745156                 0     Propriva
# 681      g989         10           49.880528                 0     Propriva
# 815      g989         15           51.325852                 1     Propriva
# 869      g989         15           53.442020                 0     Propriva
# 950      g989         20           55.326122                 1     Propriva
# 1111     g989         20           54.657650                 1     Propriva
# 1195     g989         25           56.045564                 1     Propriva
# ...

# %%
# Create a clean DataFrame by dropping the duplicate mouse by its ID.

drop_index = combinedDF[combinedDF["Mouse ID"]==str(duplicateMouseID.iloc[0,0])].index
uniqueCombinedDF = combinedDF.drop(drop_index)
#uniqueCombinedDF.reset_index(inplace=True)

uniqueCombinedDF.head()
# Out:
#   Mouse ID  Timepoint  Tumor Volume (mm3)  Metastatic Sites Drug Regimen  \
# 0     b128          0                45.0                 0    Capomulin
# 1     f932          0                45.0                 0     Ketapril
# 2     g107          0                45.0                 0     Ketapril
# 3     a457          0                45.0                 0     Ketapril
# 4     c819          0                45.0                 0     Ketapril
#
#       Sex  Age_months  Weight (g)
# 0  Female           9          22
# 1    Male          15          29
# 2  Female           2          29
# 3  Female          11          30
# 4    Male          21          25

# %%
# Checking the number of mice in the clean DataFrame.
uniqueCombinedDF["Mouse ID"].nunique()
# Out:
# 248

# %% [markdown]
# ### Summary Statistics

# %%
# Generate a summary statistics table of mean, median, variance, standard deviation, and SEM of the tumor volume for each regimen

# Use groupby and summary statistical methods to calculate the following properties of each drug regimen: 
# mean, median, variance, standard deviation, and SEM of the tumor volume. 


tVolumeMean = uniqueCombinedDF.groupby("Drug Regimen").mean()["Tumor Volume (mm3)"]
tVolumeMedian = uniqueCombinedDF.groupby("Drug Regimen").median()["Tumor Volume (mm3)"]
tVolumeVariance = uniqueCombinedDF.groupby("Drug Regimen").var()["Tumor Volume (mm3)"]
tVolumeStdDev = uniqueCombinedDF.groupby("Drug Regimen").std()["Tumor Volume (mm3)"]
tVolumeSEM = uniqueCombinedDF.groupby("Drug Regimen").sem()["Tumor Volume (mm3)"]

# Assemble the resulting series into a single summary DataFrame.

tVolumeSum = pd.DataFrame({
    "Mean Tumor Volume": tVolumeMean,
    "Median Tumor Volume": tVolumeMedian,
    "Tumor Volume Variance": tVolumeVariance,
    "Tumor Volume Std.Dev.": tVolumeStdDev,
    "Tumor Volume Std. Err.": tVolumeSEM
})

tVolumeSum
# Out:
#               Mean Tumor Volume  Median Tumor Volume  Tumor Volume Variance  \
# Drug Regimen
# Capomulin             40.675741            41.557809              24.947764
# Ceftamin              52.591172            51.776157              39.290177
# Infubinol             52.884795            51.820584              43.128684
# Ketapril              55.235638            53.698743              68.553577
# Naftisol              54.331565            52.509285              66.173479
# Placebo               54.033581            52.288934              61.168083
# Propriva              52.320930            50.446266              43.852013
# Ramicane              40.216745            40.673236              23.486704
# Stelasyn              54.233149            52.431737              59.450562
# Zoniferol             53.236507            51.818479              48.533355
#
#               Tumor Volume Std.Dev.  Tumor Volume Std. Err.
# Drug Regimen
# ...

# %%
# Generate a summary statistics table of mean, median, variance, standard deviation, 
# and SEM of the tumor volume for each regimen

sumStat = ['mean', 'median', 'var', 'std', 'sem']

# Using the aggregation method, produce the same summary statistics in a single line.

sumStatAgg =  uniqueCombinedDF.groupby(['Drug Regimen'])[['Tumor Volume (mm3)']].agg(['mean', 'median', 'var', 'std', 'sem'])
sumStatAgg
# Out:
#              Tumor Volume (mm3)
#                            mean     median        var       std       sem
# Drug Regimen
# Capomulin             40.675741  41.557809  24.947764  4.994774  0.329346
# Ceftamin              52.591172  51.776157  39.290177  6.268188  0.469821
# Infubinol             52.884795  51.820584  43.128684  6.567243  0.492236
# Ketapril              55.235638  53.698743  68.553577  8.279709  0.603860
# Naftisol              54.331565  52.509285  66.173479  8.134708  0.596466
# Placebo               54.033581  52.288934  61.168083  7.821003  0.581331
# Propriva              52.320930  50.446266  43.852013  6.622085  0.544332
# Ramicane              40.216745  40.673236  23.486704  4.846308  0.320955
# Stelasyn              54.233149  52.431737  59.450562  7.710419  0.573111
# Zoniferol             53.236507  51.818479  48.533355  6.966589  0.516398

# %% [markdown]
# ### Bar and Pie Charts

# %%
# Generate a bar plot showing the total number of timepoints for all mice tested for each drug regimen using Pandas.

# first get the number of mice per regimen
num_mice = uniqueCombinedDF["Drug Regimen"].value_counts()
# num_mice

#graph bar chart with pandas and labels
plot_pandas = num_mice.plot.bar(color='b')

plt.xlabel("Drug Regimen")
plt.ylabel("Number of Mice Tested")
# Out:
# Text(0, 0.5, 'Number of Mice Tested')

# %%
# Generate a bar plot showing the total number of timepoints for all mice tested for each drug regimen using pyplot.
x_axis = num_mice.index.values
y_axis = num_mice.values

plt.bar(x_axis, y_axis, color='b', alpha=1, align='center')

# Set the xlabel and ylabel, title using class methods
plt.xlabel("Drug Regimen")
plt.ylabel("Number of Mice Tested")
plt.xticks(rotation="vertical")

plt.show()

# %%
# Generate a pie plot showing the distribution of female versus male mice using Pandas

# first get the numbers of each sex
num_sex = uniqueCombinedDF["Sex"].value_counts()
#num_sex

num_sex.plot.pie(autopct= "%1.1f%%")
plt.show()

# %%
# Generate a pie plot showing the distribution of female versus male mice using pyplot

plot = num_sex.plot.pie(y='Total Count', autopct="%1.1f%%")
labels = ['Female', 'Male']
plt.ylabel('Sex')
plt.show()

# %% [markdown]
# ### Quartiles, Outliers and Boxplots

# %%
# Calculate the final tumor volume of each mouse across four of the treatment regimens:  
# Capomulin, Ramicane, Infubinol, and Ceftamin

# Start by getting the last (greatest) timepoint for each mouse
max_timepoint=uniqueCombinedDF.groupby(['Mouse ID'])['Timepoint'].max()
#max_timepoint 

# Merge this group df with the original DataFrame to get the tumor volume at the last timepoint
maxTimedf = pd.merge(max_timepoint , uniqueCombinedDF, on=(["Mouse ID","Timepoint"]))
maxTimedf.rename(columns={"Tumor Volume (mm3)":"Final Tumor Vol"}, inplace=True)
maxTimedf
# Out:
#     Mouse ID  Timepoint  Final Tumor Vol  Metastatic Sites Drug Regimen  \
# 0       a203         45        67.973419                 2    Infubinol
# 1       a251         45        65.525743                 1    Infubinol
# 2       a262         45        70.717621                 4      Placebo
# 3       a275         45        62.999356                 3     Ceftamin
# 4       a366         30        63.440686                 1     Stelasyn
# ..       ...        ...              ...               ...          ...
# 243     z435         10        48.710661                 0     Propriva
# 244     z578         45        30.638696                 0     Ramicane
# 245     z581         45        62.754451                 3    Infubinol
# 246     z795         45        65.741070                 3     Naftisol
# 247     z969         45        73.867845                 4     Naftisol
#
#         Sex  Age_months  Weight (g)
# 0    Female          20          23
# ...

# %%
# Put treatments into a list for for loop (and later for plot labels)
treatments = ["Capomulin", "Ramicane", "Infubinol", "Ceftamin"]

# Create empty list to fill with tumor vol data (for plotting)
tumor_vol_data = []
  
# Calculate the IQR and quantitatively determine if there are any potential outliers.   
# Locate the rows which contain mice on each drug and get the tumor volumes
for treatment in treatments:
    maxRegimen = maxTimedf.loc[maxTimedf["Drug Regimen"]==treatment,:]
    quartiles = maxRegimen["Final Tumor Vol"].quantile([.25,.5,.75])
    lowerq = quartiles[0.25]
    upperq = quartiles[0.75]
    iqr = upperq-lowerq
    lower_bound = lowerq - (1.5*iqr)
    upper_bound = upperq + (1.5*iqr)
    
# Determine outliers using upper and lower bounds
    outlier_vol = maxRegimen.loc[(maxRegimen['Final Tumor Vol'] < 
        lower_bound) | (maxRegimen['Final Tumor Vol'] > upper_bound)]
       
    if len(outlier_vol) == 0:
        print(f"\n{treatment} has no potential outliers")
    else:
        print(f"\nPotential outliers for {treatment}")
        print(outlier_vol.to_string(index=False))
            
# add subset 
    maxRegimen = maxRegimen.loc[:,"Final Tumor Vol"]
    tumor_vol_data.append(maxRegimen)
# Out:
# Capomulin has no potential outliers
#
# Ramicane has no potential outliers
#
# Potential outliers for Infubinol
# Mouse ID  Timepoint  Final Tumor Vol  Metastatic Sites Drug Regimen    Sex  Age_months  Weight (g)
#     c326          5        36.321346                 0    Infubinol Female          18          25
#
# Ceftamin has no potential outliers

# %%
# Generate a box plot that shows the distrubution of the tumor volume for each treatment group.

flierprops = dict(marker='o', markerfacecolor='r', markersize=12,
                  linestyle='none')
fig1, ax1 = plt.subplots()
ax1.set_ylabel('Final Tumor Volume (mm3)')
ax1.boxplot(tumor_vol_data, flierprops = flierprops, labels = treatments)
plt.show()

# %% [markdown]
# ### Line and Scatter Plots

# %%
# Generate a line plot of tumor volume vs. time point for a mouse treated with Capomulin
Capomulin_df = uniqueCombinedDF.loc[uniqueCombinedDF["Drug Regimen"] == "Capomulin",:]

forline_df = Capomulin_df.loc[uniqueCombinedDF["Mouse ID"] == "l509",:]
forline_df.head()
x_axis = forline_df["Timepoint"]
tumsiz = forline_df["Tumor Volume (mm3)"]

fig1, ax1 = plt.subplots()
plt.plot(x_axis, tumsiz,linewidth=2)
plt.title('Capomulin treatmeant of mouse l509')
plt.xlabel('Timepoint (Days)')
plt.ylabel('Tumor Volume (mm3)')
# Out:
# Text(0, 0.5, 'Tumor Volume (mm3)')

# %%
# Generate a scatter plot of average tumor volume vs. mouse weight for the Capomulin regimen
fig1, ax1 = plt.subplots()
avg_capm_vol =Capomulin_df.groupby(['Mouse ID']).mean()

marker_size=15
plt.scatter(avg_capm_vol['Weight (g)'],avg_capm_vol['Tumor Volume (mm3)'], color="blue")
plt.xlabel('Weight (g)',fontsize =14)
plt.ylabel('Average Tumor Volume (mm3)')
# Out:
# Text(0, 0.5, 'Average Tumor Volume (mm3)')

# %% [markdown]
# ### Correlation and Regression

# %%
# Calculate the correlation coefficient and linear regression model 
# for mouse weight and average tumor volume for the Capomulin regimen
correlation = st.pearsonr(avg_capm_vol['Weight (g)'],avg_capm_vol['Tumor Volume (mm3)'])
print(f"The correlation between mouse weight and the average tumor volume is {round(correlation[0],2)}")

capo_slope, capo_int, capo_r, capo_p, capo_std_err = st.linregress(avg_capm_vol["Weight (g)"],avg_capm_vol["Tumor Volume (mm3)"])
capo_fit = capo_slope * avg_capm_vol["Weight (g)"] + capo_int
plt.scatter(avg_capm_vol["Weight (g)"],avg_capm_vol["Tumor Volume (mm3)"],color="b")
plt.plot(avg_capm_vol["Weight (g)"],capo_fit,"--",color="r")
plt.xlabel("Weight (g)")
plt.ylabel("Average Tumor Volume (mm3)")

plt.show()
# Out:
# The correlation between mouse weight and the average tumor volume is 0.84
